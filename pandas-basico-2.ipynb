# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# 1) Percetual de acertos por assunto:
pc_mat = df_mat / 24
pc_por = df_por / 18
pc_geo = df_geo /  8
pc_ing = df_ing /  8
pc_his = df_his /  8
pc_fis = df_fis /  12
pc_qui = df_qui /  12

# %%
# 2) Total de acertos de cada aluno:
total = df_mat + df_por + df_geo + df_ing + df_his + df_fis + df_qui
total
# Out:
#     Qt_acertos
# 0           35
# 1           48
# 2           50
# 3           32
# 4           30
# ..         ...
# 95          34
# 96          27
# 97          40
# 98          40
# 99          42
#
# [100 rows x 1 columns]

# %%
# 3) Porcentual geral de cada aluno:
total/90
# Out:
#     Qt_acertos
# 0     0.388889
# 1     0.533333
# 2     0.555556
# 3     0.355556
# 4     0.333333
# ..         ...
# 95    0.377778
# 96    0.300000
# 97    0.444444
# 98    0.444444
# 99    0.466667
#
# [100 rows x 1 columns]

# %%
# 4) Quantos alunos tiveram nota maior que 45:
total_gt_45 = total[total['Qt_acertos'] > 45]
total_gt_45.count()
# Out:
# Qt_acertos    31
# dtype: int64

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# 1) DataFrame dos desqualificados por zerar em matemática, física ou química.
df_eliminados = total[(df_mat['Qt_acertos'] == 0) | 
                      (df_fis['Qt_acertos'] == 0) | 
                      (df_qui['Qt_acertos'] == 0)]

df_eliminados
# Out:
#     Qt_acertos
# 3           32
# 6           29
# 10          31
# 12          42
# 14          31
# 20          53
# 25          27
# 26          40
# 27          50
# 33          39
# 35          48
# 49          19
# 56          39
# 65          24
# 66          31
# 72          50
# 73          37
# 74          39
# 84          26
# 89          63
# 92          40
# 94          25
# 98          40

# %%
# 2) Quantos são estes alunos:

df_eliminados.count()
# Out:
# Qt_acertos    23
# dtype: int64

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
arquivo = 'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-ef46b6ea-af6b-439e-a8aa-e9033fd529d5.c000.csv'
#arquivo = 'vacinacao_acre_parte_1.csv'

# %%
# 1) Quantidade de vacinas registradas nessa base:
df = pd.read_csv(arquivo, sep=';')

# %%
df
# Out:
#                                       document_id  \
# 0       fbe28799-25d1-4201-ba7b-535d6364923d-i0b0
# 1       fad14228-9e6e-4895-8dd5-d590bceaa136-i0b0
# 2       d704d5e0-db08-4864-93ff-1c49ba1c4e44-i0b0
# 3       fadbea84-381c-4e84-920c-fdd146d96744-i0b0
# 4       d60011fe-a1b4-4d34-945e-8e041d420609-i0b0
# ...                                           ...
# 390906  a204873f-c64c-4eb5-9fea-0d4ee046130e-i0b0
# 390907  a2079d4d-8b31-49eb-ba56-ed487360869f-i0b0
# 390908  a20c5001-d4af-4eb8-991b-a62c621d16c7-i0b0
# 390909  a21f33ee-cdca-455c-9ade-55a6d387c9e8-i0b0
# 390910  a22d6003-57cb-4478-8f7e-0d7869cf85a5-i0b0
#
#                                               paciente_id  paciente_idade  \
# 0       f2fcc79a2ffb7aabbe8e31cf839b846d1c4e1bb46fd042...              11
# 1       9f7c6a218929e7cd3763aaf6174b3bd104a79d5f9fb796...              16
# 2       51dfac9ce22890c86f340ae55bdd8eb0e6159f4ace007a...               4
# 3       59ea685f572ee8be8c48fef8962167a2b96ab5627613a2...              30
# 4       b26582744d70ed052c62fe4d535cdddb2a39159e39bf11...              20
# ...                                                   ...             ...
# 390906  e36501b49b123823b8d40e97702da8ad7f5bff510c1f27...              43
# 390907  891595991c37ec5ea8f70b8d59bad9af1c59007cca3315...              33
# 390908  631ee2f84ed42247316b9bfbf152960688c9975431de8a...              39
# 390909  4d7b6c768c3a44051038953ccca29ba266a210a0fcdf5f...               3
# 390910  cfa95d9e647d505582bcfb197f7bb4a45718b982fb3323...              55
#
#        paciente_dataNascimento paciente_enumSexoBiologico  \
# 0                   2010-10-13                          M
# 1                   2005-06-27                          M
# 2                   2019-03-25                          M
# 3                   1993-11-30                          F
# 4                   2000-07-21                          F
# ...                        ...                        ...
# 390906              1978-06-22                          M
# 390907              1988-05-26                          F
# 390908              1982-10-22                          F
# 390909              2020-02-18                          F
# 390910              1966-06-23                          F
#
#         paciente_racaCor_codigo paciente_racaCor_valor  \
# 0                             4                AMARELA
# 1                            99         SEM INFORMACAO
# 2                             1                 BRANCA
# 3                             3                  PARDA
# 4                             2                  PRETA
# ...                         ...                    ...
# 390906                        3                  PARDA
# 390907                        3                  PARDA
# 390908                        4                AMARELA
# 390909                        3                  PARDA
# 390910                        3                  PARDA
#
#         paciente_endereco_coIbgeMunicipio  paciente_endereco_coPais  \
# 0                                120038.0                      10.0
# 1                                120040.0                      10.0
# 2                                120040.0                      10.0
# 3                                120040.0                      10.0
# 4                                120070.0                      10.0
# ...                                   ...                       ...
# 390906                           120040.0                      10.0
# 390907                           120038.0                      10.0
# 390908                           120013.0                      10.0
# 390909                           120005.0                      10.0
# 390910                           120040.0                      10.0
#
#        paciente_endereco_nmMunicipio  ... vacina_categoria_codigo  \
# 0                  PLACIDO DE CASTRO  ...                     NaN
# 1                         RIO BRANCO  ...                     2.0
# 2                         RIO BRANCO  ...                     2.0
# 3                         RIO BRANCO  ...                    21.0
# 4                             XAPURI  ...                     6.0
# ...                              ...  ...                     ...
# 390906                    RIO BRANCO  ...                     2.0
# 390907             PLACIDO DE CASTRO  ...                     8.0
# 390908                        BUJARI  ...                     2.0
# 390909                  ASSIS BRASIL  ...                     7.0
# 390910                    RIO BRANCO  ...                     1.0
#
#                    vacina_categoria_nome  vacina_lote  \
# 0                                    NaN       210520
# 1                           Faixa Etária       FD7221
# 2                           Faixa Etária       230165
# 3                              Gestantes       230165
# 4       Povos e Comunidades Tradicionais       210012
# ...                                  ...          ...
# 390906                      Faixa Etária       FL1939
# 390907         Trabalhadores da Educação   213VCD042Z
# 390908                      Faixa Etária       FJ4187
# 390909                   Povos Indígenas       GX6964
# 390910                      Comorbidades       FF8848
#
#                      vacina_fabricante_nome  vacina_fabricante_referencia  \
# 0                          SINOVAC/BUTANTAN                         29501
# 1                                    PFIZER   Organization/00394544000851
# 2                                  BUTANTAN                           152
# 3                                  BUTANTAN                           152
# 4                          SINOVAC/BUTANTAN   Organization/61189445000156
# ...                                     ...                           ...
# 390906                               PFIZER                         28290
# 390907                  ASTRAZENECA/FIOCRUZ   Organization/33781055000135
# 390908                               PFIZER            Organization/28290
# 390909  PFIZER - PEDIÁTRICA MENOR DE 5 ANOS                         28290
# 390910                               PFIZER            Organization/28290
#
#        vacina_dataAplicacao vacina_descricao_dose  vacina_codigo  \
# 0                2022-08-04               1ª Dose             86
# 1                2021-08-13               1ª Dose             87
# 2                2024-01-29                 Única             33
# 3                2024-03-05                 Única             33
# 4                2021-05-21               2ª Dose             86
# ...                     ...                   ...            ...
# 390906           2022-01-26               2ª Dose             87
# 390907           2021-06-17               1ª Dose             85
# 390908           2022-01-18               Reforço             87
# 390909           2023-11-24               2ª Dose            102
# 390910           2021-11-03               Reforço             87
#
#                                               vacina_nome sistema_origem
# 0                   COVID-19 SINOVAC/BUTANTAN - CORONAVAC       Novo PNI
# 1                             COVID-19 PFIZER - COMIRNATY       Novo PNI
# 2                                                    INF3       Novo PNI
# 3                                                    INF3       Novo PNI
# 4                   COVID-19 SINOVAC/BUTANTAN - CORONAVAC       Novo PNI
# ...                                                   ...            ...
# 390906                        COVID-19 PFIZER - COMIRNATY       Novo PNI
# 390907          COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 390908                        COVID-19 PFIZER - COMIRNATY       Novo PNI
# 390909  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR D...       Novo PNI
# 390910                        COVID-19 PFIZER - COMIRNATY       Novo PNI
#
# [390911 rows x 32 columns]

# %%
df.columns
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_dataNascimento', 'paciente_enumSexoBiologico',
#        'paciente_racaCor_codigo', 'paciente_racaCor_valor',
#        'paciente_endereco_coIbgeMunicipio', 'paciente_endereco_coPais',
#        'paciente_endereco_nmMunicipio', 'paciente_endereco_nmPais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumNacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoAtendimento_codigo',
#        'vacina_grupoAtendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataAplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
#        'sistema_origem'],
#       dtype='object')

# %%
df.shape[0]
# Out:
# 390911

# %%
# 2) Quantos pacientes foram vacinados:
df['paciente_id'].nunique()
# Out:
# 318850

# %%
# 3) Quantos pacientes únicos tomaram a primeira dose:
primeira_dose = df['vacina_descricao_dose'].unique()[0]
df['paciente_id'].loc[df['vacina_descricao_dose'] == primeira_dose].nunique()
# Out:
# 143753

# %%
# 3) solução alternativa
primeira_dose = df['vacina_descricao_dose'].unique()[0]
df_primeira_dose = df[df['vacina_descricao_dose'] == primeira_dose]
df_primeira_dose['paciente_id'].nunique()
# Out:
# 143753

# %%
# 4) Quantos pacientes com menos de 18 anos foram vacinados:
df_menor = df[df["paciente_idade"]<18]
df_menor['paciente_id'].nunique()
# Out:
# 69726

# %%
# 5) Quantos estabelecimentos aplicaram vacina no Acre:
df['estabelecimento_razaoSocial'].nunique()
# Out:
# 64

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1) Cópia do DataFrame original, contendo somente os registros de vacinas realizadas a menores de 18 anos:
df_menor = df[df["paciente_idade"]<18].copy()

# %%
# 2) Lista das colunas desse DataFrame com o atributo de DataFrame .columns:
df_menor.columns
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_dataNascimento', 'paciente_enumSexoBiologico',
#        'paciente_racaCor_codigo', 'paciente_racaCor_valor',
#        'paciente_endereco_coIbgeMunicipio', 'paciente_endereco_coPais',
#        'paciente_endereco_nmMunicipio', 'paciente_endereco_nmPais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumNacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoAtendimento_codigo',
#        'vacina_grupoAtendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataAplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
#        'sistema_origem'],
#       dtype='object')

# %%
# 3) Nesse DataFrame faça uma contagem do campo vacina_categoria_nome:
df_menor['vacina_categoria_nome'].value_counts()
# Out:
# vacina_categoria_nome
# Faixa Etária                                      49015
# Povos Indígenas                                    4934
# Outros                                             3755
# Povos e Comunidades Tradicionais                    875
# Trabalhadores de Saúde                              264
# Comorbidades                                         58
# População Privada de Liberdade                       53
# Gestantes                                            47
# Trabalhadores da Educação                            14
# Trabalhadores de Transporte                          13
# Pessoas com Deficiência                              11
# Pessoas Institucionalizadas                           3
# Pessoas de 60 anos ou mais institucionalizadas        1
# Puérperas                                             1
# Name: count, dtype: int64

# %%
# 4) A partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento:
lista_variaveis = [coluna for coluna in df.columns if coluna.startswith('estabelecimento')]
lista_variaveis
# Out:
# ['estabelecimento_valor',
#  'estabelecimento_razaoSocial',
#  'estabelecimento_municipio_codigo',
#  'estabelecimento_municipio_nome',
#  'estabelecimento_uf']

# %%
# 5) Usando o método .loc, selecione somente essas variáveis:
df_menor_lista = df_menor.loc[:,lista_variaveis]
df_menor_lista
# Out:
#         estabelecimento_valor  \
# 0                     2002922
# 1                     6917291
# 2                     2000482
# 10                    6917291
# 11                    6917291
# ...                       ...
# 390886                2002922
# 390887                2001829
# 390890                2000164
# 390900                6917682
# 390909                6428940
#
#                               estabelecimento_razaoSocial  \
# 0                           SECRETARIA MUNICIPAL DE SAUDE
# 1                      PREFEITURA MUNICIPAL DE RIO BRANCO
# 2                      PREFEITURA MUNICIPAL DE RIO BRANCO
# 10                     PREFEITURA MUNICIPAL DE RIO BRANCO
# 11                     PREFEITURA MUNICIPAL DE RIO BRANCO
# ...                                                   ...
# 390886                      SECRETARIA MUNICIPAL DE SAUDE
# 390887                 PREFEITURA MUNICIPAL DE RIO BRANCO
# 390890                   PREFEITURA MUNICIPAL DE TARAUACA
# 390900  DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO ...
# 390909               PREFEITURA MUNICIPAL DE ASSIS BRASIL
#
#         estabelecimento_municipio_codigo estabelecimento_municipio_nome  \
# 0                                 120038              PLACIDO DE CASTRO
# 1                                 120040                     RIO BRANCO
# 2                                 120040                     RIO BRANCO
# 10                                120040                     RIO BRANCO
# 11                                120040                     RIO BRANCO
# ...                                  ...                            ...
# 390886                            120038              PLACIDO DE CASTRO
# 390887                            120040                     RIO BRANCO
# 390890                            120060                       TARAUACA
# 390900                            120020                CRUZEIRO DO SUL
# 390909                            120005                   ASSIS BRASIL
#
#        estabelecimento_uf
# 0                      AC
# 1                      AC
# 2                      AC
# 10                     AC
# 11                     AC
# ...                   ...
# 390886                 AC
# 390887                 AC
# 390890                 AC
# 390900                 AC
# 390909                 AC
#
# [79220 rows x 5 columns]

# %%
# 6) Aplique o método .drop_duplicates e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento:
df_menor_lista = df_menor_lista.drop_duplicates()
df_menor_lista.shape
# Out:
# (205, 5)

# %%
df_menor_lista
# Out:
#         estabelecimento_valor  \
# 0                     2002922
# 1                     6917291
# 2                     2000482
# 26                    7375913
# 37                    3810771
# ...                       ...
# 149689                9846433
# 179980                2001357
# 184773                 197599
# 266929                6076017
# 343434                6411312
#
#                              estabelecimento_razaoSocial  \
# 0                          SECRETARIA MUNICIPAL DE SAUDE
# 1                     PREFEITURA MUNICIPAL DE RIO BRANCO
# 2                     PREFEITURA MUNICIPAL DE RIO BRANCO
# 26               PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 37                      PREFEITURA MUNICIPAL DE TARAUACA
# ...                                                  ...
# 149689             PREFEITURA MUNICIPAL DE MANOEL URBANO
# 179980        SECRETARIA MUNICIPAL DE SAUDE DE BRASILEIA
# 184773                CENTRAL MUNICIPAL DE REDE DE FRIOS
# 266929  ALERGOYMUNE CLINICA DE ALERGIA E IMUNIZACAO LTDA
# 343434         PREFEITURA MUNICIPAL DE PLACIDO DE CASTRO
#
#         estabelecimento_municipio_codigo estabelecimento_municipio_nome  \
# 0                                 120038              PLACIDO DE CASTRO
# 1                                 120040                     RIO BRANCO
# 2                                 120040                     RIO BRANCO
# 26                                120020                CRUZEIRO DO SUL
# 37                                120060                       TARAUACA
# ...                                  ...                            ...
# 149689                            120034                  MANOEL URBANO
# 179980                            120010                      BRASILEIA
# 184773                            120020                CRUZEIRO DO SUL
# 266929                            120040                     RIO BRANCO
# 343434                            120038              PLACIDO DE CASTRO
#
#        estabelecimento_uf
# 0                      AC
# 1                      AC
# 2                      AC
# 26                     AC
# 37                     AC
# ...                   ...
# 149689                 AC
# 179980                 AC
# 184773                 AC
# 266929                 AC
# 343434                 AC
#
# [205 rows x 5 columns]
